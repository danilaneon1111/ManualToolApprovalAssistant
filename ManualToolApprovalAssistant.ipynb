# %% [markdown]
# # Manual Tool Approval Assistant (LangChain)\n\nЭтот ноутбук демонстрирует ручное подтверждение tool calls.

# %%
# !pip -q install langchain==0.3.7 langchain-openai==0.2.9 langchain-community==0.3.7 python-dotenv==1.0.1 pydantic==2.9.2 rich==13.9.4

# %%
import os, getpass\nif not os.environ.get('OPENAI_API_KEY'):\n    os.environ['OPENAI_API_KEY'] = getpass.getpass('Enter OPENAI_API_KEY: ')\nos.environ.setdefault('LLM_MODEL','gpt-4o-mini')

# %%
from app.manual_chain import ManualToolApprovalChain\nchain = ManualToolApprovalChain()\nprint('Ready')

# %%
# Пример\nprint(chain.invoke('Скажи текущее время UTC'))
